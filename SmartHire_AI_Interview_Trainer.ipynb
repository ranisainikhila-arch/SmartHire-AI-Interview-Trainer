# %%
print("SmartHire AI Started")
# Out:
# SmartHire AI Started

# %%
# !pip install gradio
# !pip install ibm-watsonx-ai
# Out:
# Collecting gradio
#   Downloading gradio-6.20.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from gradio) (4.9.0)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading brotli-1.2.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.1 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.139.0-py3-none-any.whl.metadata (26 kB)
# Collecting gradio-client==2.5.0 (from gradio)
#   Downloading gradio_client-2.5.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting hf-gradio<1.0,>=0.4.1 (from gradio)
#   Downloading hf_gradio-0.4.1-py3-none-any.whl.metadata (428 bytes)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from gradio) (0.28.1)
# Collecting huggingface-hub<2.0,>=1.2.0 (from gradio)
#   Downloading huggingface_hub-1.23.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: jinja2<4.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from gradio) (2.0.2)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.11.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Requirement already satisfied: packaging in /opt/user-env/pyt6/lib64/python3.12/site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<4.0,>=1.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from gradio) (12.2.0)
# Collecting pydantic<=3.0,>=2.0 (from gradio)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting pydub<1.0 (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart<1.0,>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.32-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: pytz>=2017.2 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from gradio) (2025.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from gradio) (6.0.2)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<2.0,>=1.0.1 (from gradio)
#   Downloading starlette-1.3.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting tomlkit<0.15.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.26.8-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from gradio) (4.15.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.51.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: fsspec in /opt/user-env/pyt6/lib64/python3.12/site-packages (from gradio-client==2.5.0->gradio) (2025.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from anyio<5.0,>=3.0->gradio) (3.18)
# Requirement already satisfied: sniffio>=1.1 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Collecting typing-inspection>=0.4.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: certifi in /opt/user-env/pyt6/lib64/python3.12/site-packages (from httpx<1.0,>=0.24.1->gradio) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /opt/user-env/pyt6/lib64/python3.12/site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Collecting click<9.0.0,>=8.4.2 (from huggingface-hub<2.0,>=1.2.0->gradio)
#   Downloading click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock>=3.10.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from huggingface-hub<2.0,>=1.2.0->gradio) (3.20.3)
# Collecting hf-xet<2.0.0,>=1.5.1 (from huggingface-hub<2.0,>=1.2.0->gradio)
#   Downloading hf_xet-1.5.1-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from huggingface-hub<2.0,>=1.2.0->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from pandas<4.0,>=1.0->gradio) (2025.2)
# Collecting annotated-types>=0.6.0 (from pydantic<=3.0,>=2.0->gradio)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<=3.0,>=2.0->gradio)
#   Downloading pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=13.8.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from typer<1.0,>=0.12->gradio) (14.0.0)
# Requirement already satisfied: six>=1.5 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-6.20.0-py3-none-any.whl (31.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 142.9 MB/s  0:00:00m0:00:01
# Downloading gradio_client-2.5.0-py3-none-any.whl (59 kB)
# Downloading fastapi-0.139.0-py3-none-any.whl (130 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading hf_gradio-0.4.1-py3-none-any.whl (4.5 kB)
# Downloading huggingface_hub-1.23.0-py3-none-any.whl (770 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.3/770.3 kB 42.1 MB/s  0:00:00
# Downloading click-8.4.2-py3-none-any.whl (119 kB)
# Downloading hf_xet-1.5.1-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 101.3 MB/s  0:00:00
# Downloading orjson-3.11.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (134 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 84.9 MB/s  0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading python_multipart-0.0.32-py3-none-any.whl (30 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-1.3.1-py3-none-any.whl (73 kB)
# Downloading tomlkit-0.14.0-py3-none-any.whl (39 kB)
# Downloading typer-0.26.8-py3-none-any.whl (122 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading brotli-1.2.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 53.6 MB/s  0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading uvicorn-0.51.0-py3-none-any.whl (73 kB)
# Installing collected packages: pydub, brotli, typing-inspection, tomlkit, shellingham, semantic-version, python-multipart, pydantic-core, orjson, hf-xet, groovy, click, annotated-types, annotated-doc, uvicorn, starlette, pydantic, typer, safehttpx, huggingface-hub, fastapi, gradio-client, hf-gradio, gradio
#   Attempting uninstall: click90m╺━━━━━━━━━━━━━━━━━━━━━━━━  9/24 [hf-xet]c-version]
#     Found existing installation: click 8.1.8━━━━━━━━━━━━━━━━━━  9/24 [hf-xet]
#     Uninstalling click-8.1.8:━━━━━━━━━━━━━━━━━━━━━━━━  9/24 [hf-xet]
#       Successfully uninstalled click-8.1.8━━━━━━━━━━━━━━━━━━━━  9/24 [hf-xet]
#   Attempting uninstall: huggingface-hubm╺━━━━━━━━━━━ 17/24 [typer]ic]
#     Found existing installation: huggingface-hub 0.30.1━━━━━━━ 17/24 [typer]
#     Uninstalling huggingface-hub-0.30.1:m╺━━━━━━━━━━━ 17/24 [typer]
#       Successfully uninstalled huggingface-hub-0.30.1━━━━━━━━ 19/24 [huggingface-hub]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24/24 [gradio]23/24 [gradio]face-hub]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tokenizers 0.21.0 requires huggingface-hub<1.0,>=0.16.4, but you have huggingface-hub 1.23.0 which is incompatible.
# transformers 4.52.4+ibmpyeco.1 requires huggingface-hub<1.0,>=0.30.0, but you have huggingface-hub 1.23.0 which is incompatible.
# Successfully installed annotated-doc-0.0.4 annotated-types-0.7.0 brotli-1.2.0 click-8.4.2 fastapi-0.139.0 gradio-6.20.0 gradio-client-2.5.0 groovy-0.1.2 hf-gradio-0.4.1 hf-xet-1.5.1 huggingface-hub-1.23.0 orjson-3.11.9 pydantic-2.13.4 pydantic-core-2.46.4 pydub-0.25.1 python-multipart-0.0.32 safehttpx-0.1.7 semantic-version-2.10.0 shellingham-1.5.4 starlette-1.3.1 tomlkit-0.14.0 typer-0.26.8 typing-inspection-0.4.2 uvicorn-0.51.0
# Requirement already satisfied: ibm-watsonx-ai in /opt/user-env/pyt6/lib64/python3.12/site-packages (1.5.14)
# Requirement already satisfied: requests in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-watsonx-ai) (2.33.1)
# Requirement already satisfied: httpx<0.29,>=0.27 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-watsonx-ai) (0.28.1)
# Requirement already satisfied: urllib3 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-watsonx-ai) (2.7.0)
# Requirement already satisfied: pandas<2.4.0,>=0.24.2 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-watsonx-ai) (2.2.3)
# Requirement already satisfied: certifi in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-watsonx-ai) (2026.6.17)
# Requirement already satisfied: lomond in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-watsonx-ai) (0.3.3)
# Requirement already satisfied: tabulate in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-watsonx-ai) (0.9.0)
# Requirement already satisfied: packaging in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-watsonx-ai) (24.2)
# Requirement already satisfied: ibm-cos-sdk<2.15.0,>=2.12.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-watsonx-ai) (2.14.2)
# Requirement already satisfied: cachetools in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-watsonx-ai) (6.1.0)
# Requirement already satisfied: anyio in /opt/user-env/pyt6/lib64/python3.12/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /opt/user-env/pyt6/lib64/python3.12/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai) (1.0.9)
# Requirement already satisfied: idna in /opt/user-env/pyt6/lib64/python3.12/site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai) (3.18)
# Requirement already satisfied: h11>=0.16 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ibm-watsonx-ai) (0.16.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.14.2 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (2.14.2)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.14.2 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (2.14.2)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from ibm-cos-sdk-core==2.14.2->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from python-dateutil<3.0.0,>=2.9.0->ibm-cos-sdk-core==2.14.2->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from requests->ibm-watsonx-ai) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from anyio->httpx<0.29,>=0.27->ibm-watsonx-ai) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /opt/user-env/pyt6/lib64/python3.12/site-packages (from anyio->httpx<0.29,>=0.27->ibm-watsonx-ai) (4.15.0)

# %%
import gradio as gr

def interview_trainer(name, role, experience, skills):
    report = f"""
SMARTHIRE AI - PERSONALIZED INTERVIEW REPORT

Candidate Name: {name}
Target Role: {role}
Experience: {experience}
Skills: {skills}

----------------------------------
TECHNICAL INTERVIEW QUESTIONS
----------------------------------

1. Explain one project related to {role}.
2. What are the core concepts of {skills}?
3. What challenges have you faced while learning {skills}?
4. Why are you interested in becoming a {role}?

----------------------------------
HR INTERVIEW QUESTIONS
----------------------------------

1. Tell me about yourself.
2. Why should we hire you?
3. What are your strengths?
4. What are your weaknesses?
5. Where do you see yourself in 5 years?

----------------------------------
PERSONALIZED RECOMMENDATIONS
----------------------------------

• Revise the fundamentals of {skills}.
• Practice mock interviews regularly.
• Prepare at least two projects thoroughly.
• Improve communication and confidence.

----------------------------------
INTERVIEW READINESS SCORE
----------------------------------

85%

----------------------------------
7-DAY PREPARATION PLAN
----------------------------------

Day 1 : Revise fundamentals
Day 2 : Practice coding questions
Day 3 : Study projects
Day 4 : HR preparation
Day 5 : Mock interview
Day 6 : Resume review
Day 7 : Final revision
"""

    return report


demo = gr.Interface(
    fn=interview_trainer,
    inputs=[
        gr.Textbox(label="Candidate Name"),
        gr.Textbox(label="Target Job Role"),
        gr.Textbox(label="Experience"),
        gr.Textbox(label="Skills")
    ],
    outputs=gr.Textbox(label="Interview Report", lines=25),
    title="SmartHire AI - Personalized Interview Trainer",
    description="AI-powered Interview Preparation Platform using IBM Watsonx.ai and Granite Models."
)

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://43b2c96e1ebac82221.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://43b2c96e1ebac82221.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

def interview_trainer(name, role, experience, skills):

    if role.lower() == "data analyst":
        questions = """
1. What is SQL JOIN?
2. Explain normalization.
3. What is Power BI?
4. What is ETL?
"""
    elif role.lower() == "python developer":
        questions = """
1. What are decorators?
2. Explain OOP.
3. What is list comprehension?
4. What are generators?
"""
    else:
        questions = """
1. Tell me about yourself.
2. Explain one of your projects.
3. Why should we hire you?
"""

    report = f"""
SMARTHIRE AI - INTERVIEW REPORT

Candidate Name: {name}
Target Role: {role}
Experience: {experience}
Skills: {skills}

TECHNICAL QUESTIONS
{questions}

HR QUESTIONS
1. Tell me about yourself.
2. Why should we hire you?
3. What are your strengths?
4. Where do you see yourself in 5 years?

RECOMMENDATIONS
• Revise fundamentals.
• Practice mock interviews.
• Improve communication skills.
• Build projects.

INTERVIEW READINESS SCORE
85%

7-DAY PREPARATION PLAN
Day 1 - Fundamentals
Day 2 - Projects
Day 3 - Coding
Day 4 - HR Preparation
Day 5 - Mock Interview
Day 6 - Resume Review
Day 7 - Final Revision
"""

    return report


demo = gr.Interface(
    fn=interview_trainer,
    inputs=[
        gr.Textbox(label="Candidate Name"),
        gr.Textbox(label="Target Job Role"),
        gr.Textbox(label="Experience"),
        gr.Textbox(label="Skills")
    ],
    outputs=gr.Textbox(label="Interview Report", lines=25),
    title="SmartHire AI - Personalized Interview Trainer",
    description="AI-powered Interview Preparation Platform using IBM Watsonx.ai and Granite Models."
)

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * Running on public URL: https://59e83713a1c1762e25.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://59e83713a1c1762e25.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
